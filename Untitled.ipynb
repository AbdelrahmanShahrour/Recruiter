# %%
from serpapi import GoogleSearch

# %%
search = GoogleSearch({
    "q": "site:jo.linkedin.com/in (AI AND Machine Learning AND Transformers) | (AI AND Machine Learning AND Self Superfised learning)", 
    "api_key": "1835fadd674bcb5f97ec8bbf2c66cd388599e307ab40ab27f3d49b0f8345e107",
    "num": "30"
  })
result = search.get_dict()

for i in result:
    print(i)
# Out:
# search_metadata
# search_parameters
# search_information
# inline_images
# organic_results
# pagination
# serpapi_pagination

# %%
result.get("organic_results")
# Out:
# [{'position': 1,
#   'title': 'Razan Abdul_Nabi - Data Scientist - Qistas - قسطاس',
#   'link': 'https://jo.linkedin.com/in/razan-abdul-nabi-51595a1b7',
#   'displayed_link': 'https://jo.linkedin.com › ...',
#   'snippet': '1.5+ years of experience in IT and comprehensive industry knowledge of deep learning, machine learning, Artificial intelligence, Statistical modeling, ...',
#   'snippet_highlighted_words': ['deep learning',
#    'machine learning',
#    'Artificial intelligence'],
#   'about_this_result': {'keywords': ['ai',
#     'machine',
#     'learning',
#     'transformers',
#     'self',
#     'supervised'],
#    'related_keywords': ['artificial intelligence', 'deep'],
#    'languages': ['English'],
#    'regions': ['United States']},
#   'source': 'linkedin.com'},
#  {'position': 2,
#   'title': 'Osama Fityani - Computer Vision Research Assistant',
#   'link': 'https://jo.linkedin.com/in/osama-fityani',
#   'displayed_link': 'https://jo.linkedin.com › osama-fity...',
#   'snippet': 'Mechatronics Engineer, experienced in Machine Learning, Robotics, and Automation. Spending most of my time doing voluntary work where I learn and teach what ...',
#   'snippet_highlighted_words': ['Machine Learning', 'learn'],
#   'rich_snippet': {'top': {'extensions': ['عمان الأردن',
#      'Computer Vision Research Assistant',
#      'University of Jordan']}},
#   'about_this_result': {'keywords': ['ai',
#     'machine',
#     'learning',
#     'transformers',
#     'self',
#     'supervised'],
#    'languages': ['English'],
#    'regions': ['United States']},
#   'source': 'linkedin.com'},
#  {'position': 3,
#   'title': 'Rand Muhtaseb - Goethe-Institut Jordanien - عمان الأردن',
#   'link': 'https://jo.linkedin.com/in/randmuhtaseb',
#   'displayed_link': 'https://jo.linkedin.com › randmuhta...',
#   'snippet': 'Rand Muhtaseb. Machine Learning | Computer Vision | Software Engineering | Data Science | MSc | TechWomen. MBZUAI (Mohamed bin Zayed University of Artificial ...',
#   'snippet_highlighted_words': ['Machine Learning', 'Artificial'],
#   'about_this_result': {'keywords': ['ai',
#     'machine',
#     'learning',
#     'transformers',
#     'self',
#     'supervised'],
#    'languages': ['English'],
#    'regions': ['United States']},
#   'cached_page_link': '/search?q=related:https://jo.linkedin.com/in/randmuhtaseb',
#   'source': 'linkedin.com'},
#  {'position': 4,
#   'title': 'Ibrahim Shahbaz - Data Scientist - Open Insights',
#   'link': 'https://jo.linkedin.com/in/ibrahim-shahbaz-5a428aaa',
#   'displayed_link': 'https://jo.linkedin.com › ...',
#   'snippet': '*Responsible for delivering content of Python,R, Machine Learning, Data Engineering and HPC labs to undergraduate students, and assessing their performances ...',
#   'snippet_highlighted_words': ['Machine Learning'],
#   'rich_snippet': {'top': {'extensions': ['عمان عمان الأردن',
#      'Data Scientist',
#      'Open Insights']}},
#   'about_this_result': {'keywords': ['ai',
#     'machine',
#     'learning',
#     'transformers',
#     'self',
#     'supervised'],
#    'languages': ['English'],
#    'regions': ['United States']},
#   'source': 'linkedin.com'},
#  {'position': 5,
#   'title': 'Mahmoud Saber - Princess Sumaya University for ...',
#   'link': 'https://jo.linkedin.com/in/mahmoud-saber-b32137207',
#   'displayed_link': 'https://jo.linkedin.com › mahmoud-...',
#   'snippet': 'I am an ambitious, independent, hardworking, self-learner, always have a passion to work and improve my skills, eager to learn, to secure opportunities and ...',
#   'snippet_highlighted_words': ['self', 'learn'],
#   'about_this_result': {'keywords': ['ai',
#     'machine',
#     'learning',
#     'transformers',
#     'self',
#     'supervised'],
#    'languages': ['English'],
#    'regions': ['United States']},
#   'source': 'linkedin.com'},
#  {'position': 6,
#   'title': 'Ayman Al-Bitar - Data Scientist - Orange Jordan',
#   'link': 'https://jo.linkedin.com/in/ayman-al-bitar-7208baa',
#   'displayed_link': 'https://jo.linkedin.com › ...',
#   'snippet': 'Data Scientist | MLOPS| Deep Learning | ERP techno-functional Consultant ... Building Recommender Systems with Machine Learning and AI.',
#   'snippet_highlighted_words': ['Deep Learning', 'Machine Learning and AI'],
#   'rich_snippet': {'top': {'extensions': ['عمان الأردن',
#      'Data Scientist',
#      'Orange Jordan']}},
#   'about_this_result': {'keywords': ['ai',
#     'machine',
#     'learning',
#     'transformers',
#     'self',
#     'supervised'],
#    'related_keywords': ['deep'],
#    'languages': ['English'],
#    'regions': ['United States']},
#   'source': 'linkedin.com'},
#  {'position': 7,
#   'title': 'Latif Ullah Khan - Beamline Scientist - SESAME',
#   'link': 'https://jo.linkedin.com/in/latif-ullah-khan-711b95124',
#   'displayed_link': 'https://jo.linkedin.com › ...',
#   'snippet': 'In the past decade, machine learning has given us self-driving cars, practical speech ... رسم بياني Python for Data Science, AI &amp; Development ...',
#   'snippet_highlighted_words': ['machine learning', 'self', 'AI'],
#   'about_this_result': {'keywords': ['ai',
#     'machine',
#     'learning',
#     'transformers',
#     'self',
#     'supervised'],
#    'languages': ['English'],
#    'regions': ['United States']},
#   'source': 'linkedin.com'},
#  {'position': 8,
#   'title': 'Msc Arar Al Tawil - BTEC lecturer',
#   'link': 'https://jo.linkedin.com/in/msc-arar-al-tawil-990b5b14a',
#   'displayed_link': 'https://jo.linkedin.com › ...',
#   'snippet': 'Introduction to TensorFlow for Artificial Intelligence, Machine Learning ... Supervised learning algorithms can "learn" from labeled dataset and then detect ...',
#   'snippet_highlighted_words': ['Artificial Intelligence',
#    'Machine Learning',
#    'Supervised learning'],
#   'about_this_result': {'keywords': ['ai',
#     'machine',
#     'learning',
#     'transformers',
#     'self',
#     'supervised'],
#    'related_keywords': ['artificial intelligence'],
#    'languages': ['English'],
#    'regions': ['United States']},
#   'source': 'linkedin.com'},
#  {'position': 9,
#   'title': 'Mohammad Sheri, AI, CMRP - Electrical Maintenance ...',
#   'link': 'https://jo.linkedin.com/in/mohammad-sheri-ai-cmrp-61020b1a2',
#   'displayed_link': 'https://jo.linkedin.com › mohamma...',
#   'snippet': 'معرفة المزيد حول تجربة عمل Mohammad Sheri, AI, CMRP وتعليمه وزملائه ... A Cookbook of Self-Supervised Learning… ... رسم بياني Applied Machine Learning ...',
#   'snippet_highlighted_words': ['AI',
#    'Self',
#    'Supervised Learning',
#    'Machine Learning'],
#   'rich_snippet': {'top': {'extensions': ['عمان عمان الأردن',
#      'Electrical Maintenance Engineer',
#      'شركة السمرا لتوليد الكهرباء - Samra Electric Power Co.']}},
#   'about_this_result': {'keywords': ['ai',
#     'machine',
#     'learning',
#     'transformers',
#     'self',
#     'supervised'],
#    'languages': ['English'],
#    'regions': ['United States']},
#   'source': 'linkedin.com'},
#  {'position': 10,
#   'title': 'Ali Safia - Data Science and AI Team Leader - Zain',
#   'link': 'https://jo.linkedin.com/in/alisafia',
#   'displayed_link': 'https://jo.linkedin.com › alisafia',
#   'snippet': 'End-to-end Jordanian dialect speech-to-text self-supervised learning framework. Frontiers in AI and robotics \u200f20 ديسمبر، 2022 · An Online Machine Learning ...',
#   'snippet_highlighted_words': ['self',
#    'supervised learning',
#    'AI',
#    'Machine Learning'],
#   'about_this_result': {'keywords': ['ai',
#     'machine',
#     'learning',
#     'transformers',
#     'self',
#     'supervised'],
#    'languages': ['English'],
#    'regions': ['United States']},
#   'source': 'linkedin.com'},
#  {'position': 11,
#   'title': 'Omar Aloyoun - Startups Adviser - Newchip Accelerator',
#   'link': 'https://jo.linkedin.com/in/omaraloyoun',
#   'displayed_link': 'https://jo.linkedin.com › omaraloyoun',
#   'snippet': 'I drive businesses through a validated learning approach to design business ... web/mobile technologies, IoT, AI/machine learning/bots, Telecoms & ICT, ...',
#   'snippet_highlighted_words': ['learning', 'AI', 'machine learning'],
#   'about_this_result': {'keywords': ['ai',
#     'machine',
#     'learning',
#     'transformers',
#     'self',
#     'supervised'],
#    'languages': ['English'],
#    'regions': ['United States']},
#   'source': 'linkedin.com'},
#  {'position': 12,
#   'title': 'Zaid Arabiyat - Chief Executive Officer - Aces Acquisitions',
#   'link': 'https://jo.linkedin.com/in/zaid-arabiyat-27309317b',
#   'displayed_link': 'https://jo.linkedin.com › ...',
#   'snippet': 'Participated in Work & Travel program. Experienced in Data Analysis. Experienced in Machine Learning and AI. Advanced in Excel. | معرفة المزيد حول تجربة عمل ...',
#   'snippet_highlighted_words': ['Machine Learning and AI'],
#   'rich_snippet': {'top': {'extensions': ['نيو هامبشاير بورتسموث الولايات المتحدة',
#      'Chief Executive Officer',
#      'Aces Acquisitions']}},
#   'about_this_result': {'keywords': ['ai',
#     'machine',
#     'learning',
#     'transformers',
#     'self',
#     'supervised'],
#    'languages': ['English'],
#    'regions': ['United States']},
#   'source': 'linkedin.com'},
#  {'position': 13,
#   'title': 'Saeed Badran - Sr. Backend Engineer - Focus Solutions',
#   'link': 'https://jo.linkedin.com/in/sbadran',
#   'displayed_link': 'https://jo.linkedin.com › sbadran',
#   'snippet': 'Interests: Healthcare, Machine Learning, Data Science, APIs, Mobile Applications ... رسم بياني Self-Employed ... AI TensorFlow Developer Specialization.',
#   'snippet_highlighted_words': ['Machine Learning', 'Self', 'AI'],
#   'about_this_result': {'keywords': ['ai',
#     'machine',
#     'learning',
#     'transformers',
#     'self',
#     'supervised'],
#    'languages': ['English'],
#    'regions': ['United States']},
#   'cached_page_link': '/search?q=related:https://jo.linkedin.com/in/sbadran',
#   'source': 'linkedin.com'},
#  {'position': 14,
#   'title': 'Wasfi ibrahim - جامعة البلقاء التطبيقية',
#   'link': 'https://jo.linkedin.com/in/wasfi-ibrahim-3b893a1aa',
#   'displayed_link': 'https://jo.linkedin.com › ...',
#   'snippet': 'Python for machine learning. SHAI For AI | شاي للذكاء الاصطناعي. تم الإصدار في \u200fفبراير 2022. رسم بياني Google Certified digital markiting basics ...',
#   'snippet_highlighted_words': ['machine learning', 'AI'],
#   'about_this_result': {'keywords': ['ai',
#     'machine',
#     'learning',
#     'transformers',
#     'self',
#     'supervised'],
#    'languages': ['English'],
#    'regions': ['United States']},
#   'source': 'linkedin.com'},
#  {'position': 15,
#   'title': 'Yousef Majadbi - SQL Server - Support Engineer - Microsoft',
#   'link': 'https://jo.linkedin.com/in/yousef-majadbi',
#   'displayed_link': 'https://jo.linkedin.com › yousef-ma...',
#   'snippet': 'Certified in Data Science, Deep Learning, NLP, Implementing Data Warehouses, and currently pursuing a Master Track Certificate in AI and Machine Learning.',
#   'snippet_highlighted_words': ['Deep Learning', 'AI and Machine Learning'],
#   'rich_snippet': {'top': {'extensions': ['الأردن',
#      'SQL Server - Support Engineer',
#      'Microsoft']}},
#   'about_this_result': {'keywords': ['ai',
#     'machine',
#     'learning',
#     'transformers',
#     'self',
#     'supervised'],
#    'related_keywords': ['deep'],
#    'languages': ['English'],
#    'regions': ['United States']},
#   'missing': ['Self'],
#   'must_include': {'word': 'Self',
#    'link': 'https://www.google.com/search?num=30&q=site:jo.linkedin.com/in+(AI+AND+Machine+Learning+AND+Transformers)+%7C+(AI+AND+Machine+Learning+AND+%22Self%22+Supervised+learning)&sa=X&ved=2ahUKEwjW7v71gfP-AhULlGoFHYZdB0AQ5t4CegQIPBAB'},
#   'source': 'linkedin.com'},
#  {'position': 16,
#   'title': 'Mohammed Barakat - Senior Business Performance ...',
#   'link': 'https://jo.linkedin.com/in/mohammedbarakat',
#   'displayed_link': 'https://jo.linkedin.com › mohammedbarakat',
#   'snippet': '•Supervised and directed foremen and workers in the Assembly Section. ... Predicting the Usefulness of a Yelp Review Using Machine Learning.',
#   'snippet_highlighted_words': ['Supervised', 'Machine Learning'],
#   'about_this_result': {'keywords': ['ai',
#     'machine',
#     'learning',
#     'transformers',
#     'self',
#     'supervised'],
#    'languages': ['English'],
#    'regions': ['United States']},
#   'cached_page_link': '/search?q=related:https://jo.linkedin.com/in/mohammedbarakat',
#   'source': 'linkedin.com'},
#  {'position': 17,
#   'title': 'Lina Hammad - Al Hussein Technical University (HTU)',
#   'link': 'https://jo.linkedin.com/in/lina-hammad-1068a8106',
#   'displayed_link': 'https://jo.linkedin.com › ...',
#   'snippet': 'I am highly self-motivated, enthusiastic, capable of dealing with challenging ... and Informatics - Data Science and Artificial Intelligence Department.',
#   'snippet_highlighted_words': ['self', 'Artificial Intelligence'],
#   'rich_snippet': {'top': {'extensions': ['عمان الأردن',
#      'Assistant Instructor',
#      'Al Hussein Technical University (HTU)']}},
#   'about_this_result': {'keywords': ['ai',
#     'learning',
#     'transformers',
#     'self',
#     'supervised'],
#    'related_keywords': ['artificial intelligence'],
#    'languages': ['English'],
#    'regions': ['United States']},
#   'cached_page_link': '/search?q=related:https://jo.linkedin.com/in/lina-hammad-1068a8106',
#   'source': 'linkedin.com'},
#  {'position': 18,
#   'title': 'Afif Almghawish - Private Tutor - Self-employed',
#   'link': 'https://jo.linkedin.com/in/afif-almghawish-b39739ab',
#   'displayed_link': 'https://jo.linkedin.com › ...',
#   'snippet': 'Over the past 24-experienced years in the IT field, I have focused on education, research, data analysis, implementing Systems Development Life Cycle (SDLC) ...',
#   'snippet_highlighted_words': ['education'],
#   'rich_snippet': {'top': {'extensions': ['عمان الأردن',
#      'Private Tutor',
#      'Self-employed']}},
#   'about_this_result': {'keywords': ['ai',
#     'machine',
#     'learning',
#     'transformers',
#     'self',
#     'supervised'],
#    'languages': ['English'],
#    'regions': ['United States']},
#   'source': 'linkedin.com'}]
